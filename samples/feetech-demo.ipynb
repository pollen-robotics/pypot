# %%
from pypot.feetech import FeetechSTS3215IO

io = FeetechSTS3215IO(
    '/dev/tty.usbmodem58FD0164681', 
    baudrate=1000000,
    use_sync_read=True,
)
io.scan(range(10))
# Out:
# [1, 2]

# %%
io.get_model([1, 2])
# Out:
# ('FEETECH_STS3215', 'FEETECH_STS3215')

# %%
io.get_present_position([1, 2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 io.get_present_position([1, 2])
#
# File ~/Documents/feetech/src/pypot/pypot/dynamixel/io/abstract_io.py:358, in AbstractDxlIO._generate_accessors.<locals>.my_getter(self, ids, **kwargs)
#     357 def my_getter(self, ids, **kwargs):
# --> 358     return self._get_control_value(control, ids, **kwargs)
#
# File ~/Documents/feetech/src/pypot/pypot/feetech/sts3215_io.py:82, in FeetechSTS3215IO._get_control_value(self, control, ids, **kwargs)
#      80     if not models:
#      81         return ()
# ---> 82     values = [control.dxl_to_si(v, m) for v, m in zip(values, models)]
#      84 return tuple(values)
#
# TypeError: dxl_to_degree() takes 1 positional argument but 2 were given

# %%
# %timeit io.get_present_position([1, 2])
# Out:
# 1.19 ms ± 25.3 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
io.set_goal_position({1: 0, 2: 0})

# %%
io.set_goal_position({1: 0})

# %%
io.get_present_position([1, 2])
# Out:
# (-0.04, -0.22)

# %%
io.is_torque_enabled([1, 2])
# Out:
# (1, 1)

# %%
io.enable_torque([1, 2])

# %%
io.is_torque_enabled([1, 2])
# Out:
# (1, 1)

# %%
io.set_goal_position({1: 0, 2: 0})

# %%
# %timeit io.get_present_position([1, 2])
# Out:
# 1.58 ms ± 96.2 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit io.get_present_position([1])
# Out:
# 927 μs ± 84.7 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
